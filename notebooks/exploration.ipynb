# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
root_dir = "/home/tom/Projects/ag-news"
train_data = os.path.join(root_dir, "data/train.csv")
test_data = os.path.join(root_dir, "data/test.csv")

# %%
train_df = pd.read_csv(train_data)
test_df = pd.read_csv(test_data)

# %% [markdown]
# # Dataset Details
#
# https://www.kaggle.com/amananandrai/ag-news-classification-dataset
#
# - Class index: Consists of class ids 1-4 where 1-World, 2-Sports, 3-Business, 4-Sci/Tech
# - Title: Contains title of the news articles
# - Description: Contains description of the news articles

# %%
train_df.head(10)
# Out:
#    Class Index                                              Title  \
# 0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4            3  Oil prices soar to all-time record, posing new...
# 5            3        Stocks End Up, But Near Year Lows (Reuters)
# 6            3               Money Funds Fell in Latest Week (AP)
# 7            3  Fed minutes show dissent over inflation (USATO...
# 8            3                            Safety Net (Forbes.com)
# 9            3            Wall St. Bears Claw Back Into the Black
#
#                                          Description
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# ...

# %%
print(f"Training samples: {len(train_df)}")
print(f"Testing samples: {len(test_df)}")
print(f"Train/Test split: {1-len(test_df)/len(train_df):.2f}/{len(test_df)/len(train_df):.2f}")
# Out:
# Training samples: 120000
# Testing samples: 7600
# Train/Test split: 0.94/0.06

# %%
plt.hist(train_df["Class Index"])
# Out:
# (array([30000.,     0.,     0., 30000.,     0.,     0., 30000.,     0.,
#             0., 30000.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(test_df["Class Index"])
# Out:
# (array([1900.,    0.,    0., 1900.,    0.,    0., 1900.,    0.,    0.,
#         1900.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Q1 - Performing a quick analysis, what can you say about the data? Is the split train/test sensible and why?
#
# There are 120,000 training samples and 7,600 testing samples, a 94/6 split which is sufficient. 120,000 is also plenty to train a highly parametrised model such as a neural net.
#
# The class distribution is even across all 4 classes for both train and test sets so we won't carry a bias from train to test.
